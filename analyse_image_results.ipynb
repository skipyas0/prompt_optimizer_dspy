# %%
import json
import matplotlib.pyplot as plt

with open('runs/IMAGE2/prompts.jsonl') as f:
    prompts = [json.loads(line) for line in f]
with open('runs/IMAGE2/task_attempts.json') as f:
    task_attempts = json.load(f)["dev"][0]["attempts"]

# %%
by_gen = [list(filter(lambda p: p["gen"] == i, prompts)) for i in range(4)]
by_gen_ids = [list(map(lambda p: p["id"], by_gen[i])) for i in range(4)]

# %%
url_by_gen = [list(filter(lambda x: x["prompt_id"] in gen_ids, task_attempts)) for gen_ids in by_gen_ids]

# %%
import requests
for i, attempts in enumerate(url_by_gen):
    print(f"Gen {i}")
    best_wr, best_url = 0, None
    for a in attempts:
        url = a['answer']
        response = requests.get(url)
        print(url)
        pid = a['prompt_id'][:5]
        if response.status_code == 200:
            with open(f"runs/IMAGE2/images/image-gen{i}-id{pid}.jpg", "wb") as f:
                f.write(response.content)
        else:
            print("Failed to download image:", response.status_code)
# Out:
# Gen 0
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-kIZGXVlwi3GA2u4ljmjLbyCZ/user-5ctKo28YgSDJZWFTgUuP5oIC/img-GREI4B569NYhJCXVDfNFqU9e.png?st=2025-05-14T13%3A43%3A11Z&se=2025-05-14T15%3A43%3A11Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-13T19%3A57%3A49Z&ske=2025-05-14T19%3A57%3A49Z&sks=b&skv=2024-08-04&sig=MiT9i2q3mpLfobkGCrJvZcy41fAF/kwXBEQYoifqJLM%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-kIZGXVlwi3GA2u4ljmjLbyCZ/user-5ctKo28YgSDJZWFTgUuP5oIC/img-gnUFLgeekrxErcT5wFBce0TE.png?st=2025-05-14T13%3A43%3A22Z&se=2025-05-14T15%3A43%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-13T20%3A56%3A07Z&ske=2025-05-14T20%3A56%3A07Z&sks=b&skv=2024-08-04&sig=z8UGKDus5w8cahqNjnVlgR6dx9nc5ij6ChtyQWdnGqk%3D
# ...
